# %%
import pandas as pd

# %%
# DATA COLLECTION
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# INPUT AND OUTPUT SPLIT
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
                'splitter':['best', 'random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1) 
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
y_pred=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(y_pred,dependent)

# %%
# Print best parameter after tuning
re=grid.cv_results_
print("R_score value for best parameter{}:".format(grid.best_params_), r_score)
# Out:
# R_score value for best parameter{'criterion': 'absolute_error', 'splitter': 'best'}: 0.9986653772918882

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.005551      0.002948         0.001354        0.000629
# 1       0.003701      0.001763         0.001880        0.000899
# 2       0.033669      0.007092         0.001958        0.000579
# 3       0.018603      0.003754         0.001855        0.001006
# 4       0.004164      0.001872         0.000926        0.000176
# 5       0.004396      0.001625         0.002313        0.000787
# 6       0.006934      0.002455         0.001561        0.001149
# 7       0.004066      0.001464         0.001865        0.001596
#
#   param_criterion param_splitter  \
# 0   squared_error           best
# 1   squared_error         random
# 2  absolute_error           best
# 3  absolute_error         random
# 4    friedman_mse           best
# 5    friedman_mse         random
# 6         poisson           best
# 7         poisson         random
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'splitter': 'be...           0.716180
# 1  {'criterion': 'squared_error', 'splitter': 'ra...           0.669333
# 2  {'criterion': 'absolute_error', 'splitter': 'b...           0.743484
# 3  {'criterion': 'absolute_error', 'splitter': 'r...           0.741552
# 4  {'criterion': 'friedman_mse', 'splitter': 'best'}           0.716612
# 5  {'criterion': 'friedman_mse', 'splitter': 'ran...           0.654196
# 6       {'criterion': 'poisson', 'splitter': 'best'}           0.727826
# 7     {'criterion': 'poisson', 'splitter': 'random'}           0.722168
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.650171           0.728217           0.697832           0.679200
# 1           0.630512           0.731025           0.746913           0.718171
# 2           0.672149           0.718507           0.710340           0.762046
# 3           0.630150           0.710372           0.757217           0.717996
# 4           0.650663           0.728911           0.735101           0.686276
# 5           0.570052           0.680313           0.724709           0.661099
# 6           0.652136           0.761652           0.717254           0.698541
# 7           0.620205           0.699662           0.708178           0.719276
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.694320        0.027629                6
# 1         0.699191        0.043033                5
# 2         0.721305        0.030647                1
# 3         0.711457        0.043942                3
# 4         0.703513        0.031320                4
# 5         0.658074        0.050412                8
# 6         0.711482        0.036074                2
# 7         0.693898        0.037712                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 23
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[17361.7661]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
