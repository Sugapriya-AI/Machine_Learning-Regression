# %%
# INCLUDE LIBRARIES
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# DATA COLLECTION
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# Input split
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
# Output split
dependent=dataset[['charges']]

# %%
# Standardization
# Preprocessing Input data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
independent=sc.fit_transform(independent)

# %%
# Preprocessing Output data
scy=StandardScaler()
dependent=scy.fit_transform(dependent)

# %%
# Model creation using gridserch
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'C': [ 10, 100, 1000, 2000, 3000],
			  'gamma': ['auto','scale'], 
			  'kernel': ['rbf']} 
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3, n_jobs = -1) 
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# Output predict
y_pred=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(y_pred,dependent)

# %%
# Print best parameter after tuning
re=grid.cv_results_
print("R_score value for best parameter{}:".format(grid.best_params_), r_score)
# Out:
# R_score value for best parameter{'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}: 0.8390303778370944

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.090474      0.011237         0.005770        0.001939       10
# 1       0.083892      0.012740         0.004607        0.001179       10
# 2       0.396143      0.058104         0.004470        0.002271      100
# 3       0.390728      0.076975         0.005095        0.002458      100
# 4       2.916168      0.617986         0.008229        0.002668     1000
# 5       2.997389      0.680462         0.005614        0.002614     1000
# 6       5.596867      0.389616         0.004702        0.001743     2000
# 7       5.655969      0.529877         0.007635        0.003264     2000
# 8       9.237752      0.869849         0.005640        0.002703     3000
# 9       7.644237      1.280345         0.003798        0.000198     3000
#
#   param_gamma param_kernel                                          params  \
# 0        auto          rbf     {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 23
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
# Here we get preprocessed output
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[0.50834589]

# %%
# SAVE THE MODEL
import pickle
filename="Finalized_model-SVM-Grid-preprocess1_input&output.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
filename_sc = 'sc.pkl'
filename_scy = 'scy.pkl'
pickle.dump(scy, open(filename_scy, 'wb'))
pickle.dump(sc, open(filename_sc, 'wb'))

# %%
# Input preprocessing
preinput=sc.transform([[32,23,1,1,1]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-0.51314879, -1.25713795, -0.07876719,  0.98959079,  1.97058663]])

# %%
loaded_model = pickle.load(open("Finalized_model-SVM-Grid-preprocess1_input&output.sav", 'rb'))
result = loaded_model.predict(preinput)

# %%
result
# Out:
# array([-0.00034067])

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput
# Out:
# array([[13266.2982996]])
